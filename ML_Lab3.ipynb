# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanskritis101/LetTheMachineLearn/blob/main/ML_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv("/content/drive/MyDrive/Heart/temperatures.csv")
df
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 0    1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47
# 1    1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80
# 2    1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85
# 3    1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04
# 4    1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112  2013  24.56  26.59  30.62  32.66  34.46  32.44  31.07  30.76  31.04
# 113  2014  23.83  25.97  28.95  32.74  33.77  34.15  31.85  31.32  30.68
# 114  2015  24.58  26.89  29.07  31.87  34.09  32.48  31.88  31.52  31.55
# 115  2016  26.94  29.72  32.62  35.38  35.72  34.03  31.64  31.79  31.66
# 116  2017  26.45  29.46  31.60  34.95  35.84  33.82  31.88  31.72  32.22
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# ...

# %%
df.describe()
# Out:
#               YEAR         JAN         FEB         MAR         APR  \
# count   117.000000  117.000000  117.000000  117.000000  117.000000
# mean   1959.000000   23.687436   25.597863   29.085983   31.975812
# std      33.919021    0.834588    1.150757    1.068451    0.889478
# min    1901.000000   22.000000   22.830000   26.680000   30.010000
# 25%    1930.000000   23.100000   24.780000   28.370000   31.460000
# 50%    1959.000000   23.680000   25.480000   29.040000   31.950000
# 75%    1988.000000   24.180000   26.310000   29.610000   32.420000
# max    2017.000000   26.940000   29.720000   32.620000   35.380000
#
#               MAY         JUN         JUL         AUG         SEP         OCT  \
# count  117.000000  117.000000  117.000000  117.000000  117.000000  117.000000
# mean    33.565299   32.774274   31.035897   30.507692   30.486752   29.766581
# std      0.724905    0.633132    0.468818    0.476312    0.544295    0.705492
# ...

# %% [markdown]
# # a. Apply Linear Regression using suitable library function and predict the Month-wise Temperature.

# %%
x_train = df["YEAR"]
y_train = df["ANNUAL"]
x = x_train.values
y = y_train.values
x.shape
# Out:
# (117,)

# %%
y.shape
# Out:
# (117,)

# %%
x = x.reshape(117,1)
y = y.reshape(117,1)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# # b. Assess the performance of regression models using MSE, MAE and R-Square metrics

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
predicted = regressor.predict(x)

# %% [markdown]
# Mean Squared Error (MSE) :-

# %%
mse = mean_squared_error(y,predicted)
print("Mean Squared Error:",mse)
# Out:
# Mean Squared Error: 0.10960795229110352

# %% [markdown]
# Mean Absolute Error (MAE) :-

# %%
mae = mean_absolute_error(y,predicted)
print("Mean Absolute Error:",mae)
# Out:
# Mean Absolute Error: 0.22535284978630413

# %% [markdown]
# R-square :-

# %%
r2 = r2_score(y, predicted)
print("R-square:",r2)
# Out:
# R-square: 0.6418078912783682

# %% [markdown]
# # c. Visualize simple regression model.

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y, label="Actual", color="blue")
plt.plot(x, predicted, label="Predicted", color="red", linewidth=3)
plt.xlabel("Year")
plt.ylabel("Temperature")
plt.title("Annual temperature")
plt.legend()
